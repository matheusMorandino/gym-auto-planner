# %%
import os
import pandas as pd

# %%
ROOT_DIR = os.path.dirname(os.getcwd())

ROOT_DIR
# Out:
# 'C:\\Users\\matheus.carneiro\\Projetos\\gym-auto-planner'

# %%
df_raw = pd.read_csv(os.path.join(ROOT_DIR, 'datasets', 'gym_exercise_dataset.csv'))

df_raw.head()
# Out:
#           Exercise Name             Equipment Variation             Utility  \
# 0          Neck Flexion                 Cable        No  Basic or Auxiliary
# 1          Neck Flexion  Lever (plate loaded)        No  Basic or Auxiliary
# 2  Lateral Neck Flexion  Lever (plate loaded)        No           Auxiliary
# 3          Neck Flexion  Lever (selectorized)        No  Basic or Auxiliary
# 4  Lateral Neck Flexion  Lever (selectorized)        No           Auxiliary
#
#   Mechanics Force                                        Preparation  \
# 0  Isolated  Pull  Sit on bench facing away from middle pulley. P...
# 1  Isolated  Pull  Sit on seat in machine. Position padded lever ...
# 2  Isolated  Pull  Sit on seat in machine with feet apart   . Pos...
# 3  Isolated  Pull  Sit on seat in machine. Position padded lever ...
# 4  Isolated  Pull  Sit on seat in machine with feet apart. Positi...
#
#                                            Execution        Target_Muscles  \
# ...

# %%
muscle_groups = df_raw[['Target_Muscles', 'Secondary Muscles']]

muscle_groups.head()
# Out:
#          Target_Muscles                      Secondary Muscles
# 0  Sternocleidomastoid,                    Sternocleidomastoid
# 1  Sternocleidomastoid,                    Sternocleidomastoid
# 2  Sternocleidomastoid,  Sternocleidomastoid, Levator Scapulae
# 3  Sternocleidomastoid,                    Sternocleidomastoid
# 4  Sternocleidomastoid,  Sternocleidomastoid, Levator Scapulae

# %%
muscle_groups['full_set'] = muscle_groups.apply(
    lambda x: x['Target_Muscles'] + (x['Secondary Muscles'] if isinstance(x['Secondary Muscles'], str) else ''),
    axis=1)

muscle_groups.head()
# Out:
#          Target_Muscles                      Secondary Muscles  \
# 0  Sternocleidomastoid,                    Sternocleidomastoid
# 1  Sternocleidomastoid,                    Sternocleidomastoid
# 2  Sternocleidomastoid,  Sternocleidomastoid, Levator Scapulae
# 3  Sternocleidomastoid,                    Sternocleidomastoid
# 4  Sternocleidomastoid,  Sternocleidomastoid, Levator Scapulae
#
#                                             full_set
# 0            Sternocleidomastoid,Sternocleidomastoid
# 1            Sternocleidomastoid,Sternocleidomastoid
# 2  Sternocleidomastoid,Sternocleidomastoid, Levat...
# 3            Sternocleidomastoid,Sternocleidomastoid
# 4  Sternocleidomastoid,Sternocleidomastoid, Levat...

# %%
list_muscles = [group.split(',') for group in muscle_groups['full_set'].tolist()]

list_muscles = [muscle.strip() for group in list_muscles for muscle in group]

set(list_muscles)
# Out:
# {'',
#  'Adductors',
#  'Anterior Deltoid',
#  'Biceps Brachii',
#  'Brachialis',
#  'Brachioradialis',
#  'Erector Spinae',
#  'Gastrocnemius',
#  'Gluteus Maximus',
#  'Gluteus MaximusErector Spinae',
#  'Hamstrings',
#  'HamstringsHamstrings',
#  'Hip Abductors',
#  'Hip Adductors',
#  'Hip Flexors',
#  'Hip FlexorsHip Flexors',
#  'Hip FlexorsIliopsoas',
#  'Hip FlexorsObliques',
#  'Hip FlexorsRectus Abdominis',
#  'Infraspinatus',
#  'Lateral Deltoid',
#  'Latissimus Dorsi',
#  'Levator Scapulae',
#  'Lower Trapezius',
#  'Middle Trapezius',
#  'Obliques',
#  'Pectoralis Major Clavicular',
#  'Pectoralis Major Sternal',
#  'Pectoralis Major SternalTriceps Brachii',
#  'Pectoralis Minor',
#  'Posterior Deltoid',
#  'Pronators',
#  'Quadratus Lumborum',
#  'Quadriceps',
#  'Rectus Abdominis',
#  'Rhomboids',
#  'Serratus Anterior',
#  'Soleus',
#  'Splenius',
#  'Sternocleidomastoid',
#  'Subscapularis',
#  'Supinator',
#  'Supraspinatus',
#  'Teres Major',
#  'Teres Minor',
# ...

# %%
muscle_groups['target_count'] = muscle_groups.apply(lambda x: len([m for m in x['Target_Muscles'].split(',') if len(m.strip()) > 0]), axis=1)

muscle_groups[muscle_groups['target_count'] > 1]
# Out:
#                                         Target_Muscles  \
# 166  Latissimus Dorsi, Lower Trapezius, Rhomboids, ...
# 167  Latissimus Dorsi, Lower Trapezius, Rhomboids, ...
# 168  Latissimus Dorsi, Lower Trapezius, Rhomboids, ...
# 169  Latissimus Dorsi, Lower Trapezius, Rhomboids, ...
# 170  Latissimus Dorsi, Lower Trapezius, Rhomboids, ...
# ..                                                 ...
# 253                        Infraspinatus, Teres Minor,
# 254                        Infraspinatus, Teres Minor,
# 255                        Infraspinatus, Teres Minor,
# 256                        Infraspinatus, Teres Minor,
# 257                        Infraspinatus, Teres Minor,
#
#                         Secondary Muscles  \
# 166  Biceps Brachii, Trapezius, Rhomboids
# 167  Biceps Brachii, Trapezius, Rhomboids
# 168  Biceps Brachii, Trapezius, Rhomboids
# 169  Biceps Brachii, Trapezius, Rhomboids
# 170  Biceps Brachii, Trapezius, Rhomboids
# ..                                    ...
# ...

# %%
df_raw['Equipment'].apply(lambda x: ' '.join(x.split()).replace('\u200b','')).drop_duplicates().to_list()
# Out:
# ['Cable',
#  'Lever (plate loaded)',
#  'Lever (selectorized)',
#  'Weighted',
#  'Body Weight',
#  'Suspended',
#  'Band Resistive',
#  'Isometric',
#  'Barbell',
#  'Dumbbell',
#  'Sled',
#  'Smith',
#  'Assisted',
#  'Band-assisted',
#  'Self-assisted',
#  'Sled (selectorized)',
#  'Sled (plate loaded)',
#  'Assisted (machine)',
#  'Assisted (partner)',
#  'Suspension',
#  'Plyometric',
#  'Assisted Chest Dip',
#  'Cable Standing Fly',
#  'Lever (selectorized) Chest Dip',
#  'Weighted Chest Dip',
#  'Cable (pull side)',
#  'Lever']
